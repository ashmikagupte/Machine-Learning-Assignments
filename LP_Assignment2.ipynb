# %% [markdown]
# **Ashmika Gupte(33228)**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path ="/content/drive/MyDrive/temperatures.csv"
df=pd.read_csv(path)

# %%
df
# Out:
#      YEAR    JAN    FEB    MAR  ...  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0    1901  22.40  24.14  29.07  ...    23.27    31.46    31.27    27.25
# 1    1902  24.93  26.58  29.77  ...    25.75    31.76    31.09    26.49
# 2    1903  23.44  25.03  27.83  ...    24.24    30.71    30.92    26.26
# 3    1904  22.50  24.73  28.21  ...    23.62    30.95    30.66    26.40
# 4    1905  22.00  22.83  26.68  ...    22.25    30.00    31.33    26.57
# ..    ...    ...    ...    ...  ...      ...      ...      ...      ...
# 112  2013  24.56  26.59  30.62  ...    25.58    32.58    31.33    27.83
# 113  2014  23.83  25.97  28.95  ...    24.90    31.82    32.00    27.81
# 114  2015  24.58  26.89  29.07  ...    25.74    31.68    31.87    28.27
# 115  2016  26.94  29.72  32.62  ...    28.33    34.57    32.28    30.03
# 116  2017  26.45  29.46  31.60  ...    27.95    34.13    32.41    29.69
#
# [117 rows x 18 columns]

# %%
df.shape
# Out:
# (117, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     117 non-null    int64
#  1   JAN      117 non-null    float64
#  2   FEB      117 non-null    float64
#  3   MAR      117 non-null    float64
#  4   APR      117 non-null    float64
#  5   MAY      117 non-null    float64
#  6   JUN      117 non-null    float64
#  7   JUL      117 non-null    float64
#  8   AUG      117 non-null    float64
#  9   SEP      117 non-null    float64
#  10  OCT      117 non-null    float64
#  11  NOV      117 non-null    float64
#  12  DEC      117 non-null    float64
#  13  ANNUAL   117 non-null    float64
#  14  JAN-FEB  117 non-null    float64
#  15  MAR-MAY  117 non-null    float64
#  16  JUN-SEP  117 non-null    float64
#  17  OCT-DEC  117 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 16.6 KB

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB  ...     MAR-MAY     JUN-SEP     OCT-DEC
# count   117.000000  117.000000  117.000000  ...  117.000000  117.000000  117.000000
# mean   1959.000000   23.687436   25.597863  ...   31.517607   31.198205   27.208120
# std      33.919021    0.834588    1.150757  ...    0.740585    0.420508    0.672003
# min    1901.000000   22.000000   22.830000  ...   29.920000   30.240000   25.740000
# 25%    1930.000000   23.100000   24.780000  ...   31.040000   30.920000   26.700000
# 50%    1959.000000   23.680000   25.480000  ...   31.470000   31.190000   27.210000
# 75%    1988.000000   24.180000   26.310000  ...   31.890000   31.400000   27.610000
# max    2017.000000   26.940000   29.720000  ...   34.570000   32.410000   30.030000
#
# [8 rows x 18 columns]

# %%
plt.scatter(df['YEAR'],df['ANNUAL'],color='red', alpha=0.7)
plt.xlabel('YEAR')
plt.ylabel('ANNUAL TEMP')
plt.title('ANNUAL TEMP THROUGH OUT YEARS')
plt.grid(True, linewidth= 1, linestyle="--")

# %%
temp_range = [20,22,24,26,28,30,32,34,36]
fig, axes = plt.subplots(figsize=(8,8),nrows=2, ncols=2)

ax1 = plt.subplot(2,2,1)
ax1.hist(df['JAN-FEB'], temp_range)
ax1.title.set_text('JAN-FEB')
plt.xlabel('AVERAGE TEMPERATURE')
plt.ylabel('FREQUENCY')


ax2 = plt.subplot(2,2,2)
ax2.hist(df['MAR-MAY'], temp_range)
ax2.title.set_text('MAR-MAY')
plt.xlabel('AVERAGE TEMPERATURE')
plt.ylabel('FREQUENCY')

ax3 = plt.subplot(2,2,3)
ax3.hist(df['JUN-SEP'], temp_range)
ax3.title.set_text('JUN-SEP')
plt.xlabel('AVERAGE TEMPERATURE')
plt.ylabel('FREQUENCY')

ax4 = plt.subplot(2,2,4)
ax4.hist(df['OCT-DEC'], temp_range)
ax4.title.set_text('OCT-DEC')
plt.xlabel('AVERAGE TEMPERATURE')
plt.ylabel('FREQUENCY')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)

# %%
def plot_graph(column):
    plt.plot(df['YEAR'],df[column],color='purple')
    plt.xlabel('YEAR')
    plt.ylabel(column)
    plt.title('TEMP IN THE MONTH OF '+column+' THROUGH OUT THE YEARS')

# %%
plot_graph('JAN')

# %%
plot_graph('JUN')

# %%
plt.figure(figsize=(10,10))
plt.plot(df['YEAR'],df['JAN-FEB'],label='JAN-FEB',color='hotpink', 
      linestyle='-', linewidth=1)
plt.plot(df['YEAR'],df['MAR-MAY'],label='MAR-MAY',color='mediumorchid', 
      linestyle='-', linewidth=1)
plt.plot(df['YEAR'],df['JUN-SEP'],label='JUN-SEP',color='gold', 
      linestyle='-', linewidth=1)
plt.plot(df['YEAR'],df['OCT-DEC'],label='OCT-DEC',color='mediumseagreen', 
      linestyle='-', linewidth=1)
plt.xlabel('YEAR')
plt.ylabel('TEMP')
plt.title('TEMPERATURE THROUGH OUT YEARS')
plt.grid(True, linewidth= 1, linestyle="--")
plt.legend()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
def LinearRegr(column):
    y1 = df[[column]]
    X1 = df[['YEAR']]
    X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.3, random_state=0)
    reg = LinearRegression().fit(X_train, y_train)
    preds = reg.predict(X_test)
    print ("MSE      : " , mean_squared_error(y_test, preds))
    print ("MAE      : " , mean_absolute_error(y_test, preds))
    print ("R2 score : ", r2_score(y_test, preds))
    b0 = reg.coef_
    b1 = reg.intercept_
    print ("========================================")
    data = pd.DataFrame(X_test)
    data['ACTUAL'] = y_test
    data['PRED'] = preds
    print (data.head())
    print ("========================================")
    plt.scatter(data['YEAR'],data['ACTUAL'],c='red', alpha = 0.7)
    plt.plot(X_train,b0*X_train+b1,c='purple')
    plt.title("Linear Regression for "+column)
    plt.xlabel("YEAR")
    plt.ylabel("TEMPERATURE")

# %%
LinearRegr('JAN')
# Out:
# MSE      :  0.6080338203121165
# MAE      :  0.6231302838065338
# R2 score :  0.27921723515312413
# ...
#     YEAR  ACTUAL       PRED
# 10  1911   23.22  22.950664
# 59  1960   23.78  23.613631
# 95  1996   25.18  24.100710
# 91  1992   23.84  24.046590
# 7   1908   23.57  22.910074
# ...

# %%
LinearRegr('MAR')
# Out:
# MSE      :  0.7216688063438201
# MAE      :  0.697896354102514
# R2 score :  0.4637802650982116
# ...
#     YEAR  ACTUAL       PRED
# 10  1911   27.04  28.423304
# 59  1960   28.04  29.106379
# 95  1996   30.86  29.608231
# 91  1992   28.89  29.552469
# 7   1908   28.86  28.381483
# ...

# %%
LinearRegr('ANNUAL')
# Out:
# MSE      :  0.14516479343842795
# MAE      :  0.2501753025103757
# R2 score :  0.6832202846026354
# ...
#     YEAR  ACTUAL       PRED
# 10  1911   28.62  28.612705
# 59  1960   29.31  29.179208
# 95  1996   29.58  29.595415
# 91  1992   29.23  29.549170
# 7   1908   28.83  28.578021
# ...

# %%
LinearRegr('JUN')
# Out:
# MSE      :  0.34557114666990135
# MAE      :  0.49336613247548844
# R2 score :  0.22224496114579506
# ...
#     YEAR  ACTUAL       PRED
# 10  1911   32.23  32.499276
# 59  1960   33.17  32.761661
# 95  1996   32.50  32.954433
# 91  1992   33.16  32.933014
# 7   1908   33.12  32.483212
# ...

# %%
LinearRegr('NOV')
# Out:
# MSE      :  0.3212796209633544
# MAE      :  0.4439269346093027
# R2 score :  0.5158919406723997
# ...
#     YEAR  ACTUAL       PRED
# 10  1911   25.70  26.642226
# 59  1960   26.92  27.319634
# 95  1996   27.61  27.817322
# 91  1992   27.55  27.762023
# 7   1908   26.88  26.600752
# ...

# %%
# %%shell
# jupyter nbconvert --to html /content/LP_Assignment2.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/LP_Assignment2.ipynb to html
# [NbConvertApp] Writing 609119 bytes to /content/LP_Assignment2.html
